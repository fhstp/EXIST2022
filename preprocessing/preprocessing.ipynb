# %%
import pandas as pd
import numpy as np
import re
import string
import ftfy
import sklearn
from sklearn.model_selection import train_test_split

# %%
path = ("data/EXIST2021_training.tsv")
df = pd.read_csv(path, sep="\t")
df
# Out:
#       test_case    id   source language  \
# 0     EXIST2021     1  twitter       en
# 1     EXIST2021     2  twitter       en
# 2     EXIST2021     3  twitter       en
# 3     EXIST2021     4  twitter       en
# 4     EXIST2021     5  twitter       en
# ...         ...   ...      ...      ...
# 6972  EXIST2021  6973  twitter       es
# 6973  EXIST2021  6974  twitter       es
# 6974  EXIST2021  6975  twitter       es
# 6975  EXIST2021  6976  twitter       es
# 6976  EXIST2021  6977  twitter       es
#
#                                                    text       task1  \
# 0     She calls herself "anti-feminazi" how about sh...      sexist
# 1     Now, back to these women, the brave and the be...  non-sexist
# 2     @CurvyBandida @Xalynne_B Wow, your skirt is ve...      sexist
# 3     @AurelieGuiboud Incredible!  Beautiful!But I l...  non-sexist
# 4     i find it extremely hard to believe that kelly...  non-sexist
# ...

# %%
def do_split(df):
    df_EN = df
    df_ES = df
    df_EN = df.loc[df["language"] == "en"]
    df_ES = df.loc[df["language"] == "es"]
    return df_EN, df_ES

# %%
df_EN, df_ES = do_split(df)

# %%
def remove_punctuation(text):
    text = "".join([c for c in text if c not in string.punctuation])
    return text

def remove_hashtags(text):
    text = re.sub(r"#(\w+)", ' ', text)
    return text

def remove_mentions(text):
    text = re.sub(r"@(\w+)", ' ', text)
    return text

def remove_links(text):
    text = re.sub(r"http\S+", "", text)
    return text

def remove_digits(text):
    text = re.sub(r'\d+', '', text) 
    return text

def remove_nonASCII(text):
    text = re.sub(r"[^\x00-\x7F]+", " ", text)
    return text

def remove_nonASCII_ES(text):
    text = re.sub(u"\u00BF", " ", text)
    return text

def remove_whitespace(text):
    text = text.strip()
    return text

# %% [markdown]
# ## Only Punctuation

# %%
df_EN["text"] = df_EN.text.apply(remove_punctuation)
# Out:
# /home/schuetzm/anaconda3/envs/exist_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       test_case    id   source language  \
# 0     EXIST2021     1  twitter       en
# 1     EXIST2021     2  twitter       en
# 2     EXIST2021     3  twitter       en
# 3     EXIST2021     4  twitter       en
# 4     EXIST2021     5  twitter       en
# ...         ...   ...      ...      ...
# 3431  EXIST2021  3432  twitter       en
# 3432  EXIST2021  3433  twitter       en
# 3433  EXIST2021  3434  twitter       en
# 3434  EXIST2021  3435  twitter       en
# 3435  EXIST2021  3436  twitter       en
#
# ...

# %% [markdown]
# ## Only Hashtags

# %%
df_EN["text"] = df_EN.text.apply(remove_hashtags)
# Out:
# /home/schuetzm/anaconda3/envs/exist_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       test_case    id   source language  \
# 0     EXIST2021     1  twitter       en
# 1     EXIST2021     2  twitter       en
# 2     EXIST2021     3  twitter       en
# 3     EXIST2021     4  twitter       en
# 4     EXIST2021     5  twitter       en
# ...         ...   ...      ...      ...
# 3431  EXIST2021  3432  twitter       en
# 3432  EXIST2021  3433  twitter       en
# 3433  EXIST2021  3434  twitter       en
# 3434  EXIST2021  3435  twitter       en
# 3435  EXIST2021  3436  twitter       en
#
# ...

# %% [markdown]
# ## Without usernames, hashtags, numbers, punctuation, links, non-ASCII

# %%
#trainingEN["text"] = trainingEN.text.apply(remove_mentions)
#trainingEN["text"] = trainingEN.text.apply(remove_hashtags)
#trainingEN["text"] = trainingEN.text.apply(remove_digits)
#trainingEN["text"] = trainingEN.text.apply(remove_punctuation)
#trainingEN["text"] = trainingEN.text.apply(remove_links)
#trainingEN["text"] = trainingEN.text.apply(remove_nonASCII)

# %% [markdown]
# ## Without usernames, hashtags, links

# %%
trainingEN["text"] = trainingEN.text.apply(remove_mentions)
trainingEN["text"] = trainingEN.text.apply(remove_hashtags)
trainingEN["text"] = trainingEN.text.apply(remove_links)
trainingEN
# Out:
# /home/schuetzm/anaconda3/envs/exist_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/schuetzm/anaconda3/envs/exist_env/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/schuetzm/anaconda3/envs/exist_env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## Train / test split

# %%
train_inputs, validation_inputs= train_test_split(df, random_state=42, test_size=0.1)

# %%
#train_inputs.to_csv("training_split.tsv", sep="\t")
#validation_inputs.to_csv("validation_split.tsv", sep="\t")
